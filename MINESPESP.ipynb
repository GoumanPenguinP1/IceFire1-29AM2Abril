# %%
# Esta es una modificacion del script original para google colab, para que funcione en github codespaces
# Hecho por @LUCAST o @Lucast1574 o @Lucast_1574 en github y otras redes sociales
# Versiones disponibles testeadas:
# - 1.20.4
# - 1.20.3
# - 1.20.2
# - 1.20.1
# - 1.20
# - 1.19.4
# - 1.19.3
# - 1.19.2
# - 1.19.1
# - 1.19
# - 1.18.2
# - 1.18.1
# - 1.18
# - 1.17.1
# - 1.17
# - 1.16.5
# - 1.16.4
# - 1.16.3
# - 1.15.2
# - 1.14.4
# - 1.13.2
# - 1.12.2
# - 1.11.2
# - 1.10.2
# - 1.9.4
# - 1.8.8


version = '1.20.1' # Version de Minecraft a usar

#Chose server type. Currently available versions:
# - paper (Lo más vanilla. Es lo mismo que SPIGOT, bukkit, etc)
# - forge (Para usar MODS. Es básicamente FORGE) [Aviso, la instalación tarda APROX 10-15 min, al ejecutar el primer paso, esperar a que ponga COMPLETADO]
# - fabric (Para jugar Fabric. Es una alternativa a Forge)
# - vanilla (Minecraft Vanilla sin mods ni plugins)
# - snapshot (En "version" tendrás que poner el nombre de la SNAPSHOT, EJ: 23w42a)
# - mohist (Versión de Minecraft que combina Forge y Bukkit)

server_type = 'mohist'

#Importa librerias necesarias para el funcionamiento del script

import os
import requests
import json


server_directory = "Minecraft-server"

# Crea el directorio del servidor en codespace

os.makedirs(server_directory, exist_ok=True)
os.chdir(server_directory)

# Inicio interno... Descarga el servidor

if server_type == 'paper':
    a = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version)

    b = requests.get("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]))

    print("https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"])
    serverURL = "https://papermc.io/api/v2/projects/paper/versions/" + version + "/builds/" + str(a.json()["builds"][-1]) + "/downloads/" + b.json()["downloads"]["application"]["name"]

if server_type == 'forge':
    serverURL = "https://serverjars.com/api/fetchJar/modded/forge/" + version

if server_type == 'vanilla':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/vanilla/" + version

if server_type == 'snapshot':
    serverURL = "https://serverjars.com/api/fetchJar/vanilla/snapshot/" + version
if server_type == 'fabric':
    serverURL = 'https://maven.fabricmc.net/net/fabricmc/fabric-installer/0.11.2/fabric-installer-0.11.2.jar'

if server_type == 'mohist':
    serverURL = "https://serverjars.com/api/fetchJar/modded/mohist/" + version

jar_name = {'paper': 'server.jar', 'fabric': 'fabric-installer.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': "snapshot.jar", 'mohist': "mohist.jar"}

print('Descargando el tipo de servidor: ')

if serverURL:
    print('Descargando a GitHub Codespaces...')
    r = requests.get(serverURL)

    if r.status_code == 200:
        with open(jar_name[server_type], 'wb') as f:
            f.write(r.content)
    else:
        print('Error '+ str(r.status_code) + '! La versión que has elegido probablemente no funciona.')


# Correr en un camino especifico

if server_type == 'fabric':
    # !java -jar fabric-installer.jar server -mcversion $version -downloadMinecraft

if server_type == 'forge':
    # %cd "/workspaces/codespaces-jupyter/Minecraft-server"
    # !java -jar forge.jar --installServer

# Guarda el archivo de configuración localmente
colabconfig = {"server_type": server_type, "server_version": version}
with open("colabconfig.json", 'w') as config_file:
    json.dump(colabconfig, config_file)

# Imprime un mensaje de finalización
print('Completado!')
# Cambie el eula a true para aceptar los términos de Minecraft
# !echo "eula=true" >> eula.txt
# Out:
# Descargando el tipo de servidor:
# Descargando a GitHub Codespaces...
# Completado!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/utils/_process_posix.py:151, in ProcessHandler.system(self, cmd)
#     150 else:
# --> 151     child = pexpect.spawn(self.sh, args=['-c', cmd])  # Vanilla Pexpect
#     152 flush = sys.stdout.flush
#
# File ~/.local/lib/python3.10/site-packages/pexpect/pty_spawn.py:205, in spawn.__init__(self, command, args, timeout, maxread, searchwindowsize, logfile, cwd, env, ignore_sighup, echo, preexec_fn, encoding, codec_errors, dimensions, use_poll)
#     204 else:
# --> 205     self._spawn(command, args, preexec_fn, dimensions)
#     206 self.use_poll = use_poll
#
# File ~/.local/lib/python3.10/site-packages/pexpect/pty_spawn.py:303, in spawn._spawn(self, command, args, preexec_fn, dimensions)
#     300     self.args = [a if isinstance(a, bytes) else a.encode(self.encoding)
#     301                  for a in self.args]
# --> 303 self.ptyproc = self._spawnpty(self.args, env=self.env,
#     304                              cwd=self.cwd, **kwargs)
#     306 self.pid = self.ptyproc.pid
#
# File ~/.local/lib/python3.10/site-packages/pexpect/pty_spawn.py:315, in spawn._spawnpty(self, args, **kwargs)
#     314 '''Spawn a pty and return an instance of PtyProcess.'''
# --> 315 return ptyprocess.PtyProcess.spawn(args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/ptyprocess/ptyprocess.py:315, in PtyProcess.spawn(cls, argv, cwd, env, echo, preexec_fn, dimensions, pass_fds)
#     314 os.close(exec_err_pipe_write)
# --> 315 exec_err_data = os.read(exec_err_pipe_read, 4096)
#     316 os.close(exec_err_pipe_read)
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[10], line 114
#     112 print('Completado!')
#     113 # Cambie el eula a true para aceptar los términos de Minecraft
# --> 114 get_ipython().system('echo "eula=true" >> eula.txt')
#
# File ~/.local/lib/python3.10/site-packages/ipykernel/zmqshell.py:657, in ZMQInteractiveShell.system_piped(self, cmd)
#     655         self.user_ns["_exit_code"] = system(cmd)
#     656 else:
# --> 657     self.user_ns["_exit_code"] = system(self.var_expand(cmd, depth=1))
#
# File ~/.local/lib/python3.10/site-packages/IPython/utils/_process_posix.py:167, in ProcessHandler.system(self, cmd)
#     162         out_size = len(child.before)
#     163 except KeyboardInterrupt:
#     164     # We need to send ^C to the process.  The ascii code for '^C' is 3
#     165     # (the character is known as ETX for 'End of Text', see
#     166     # curses.ascii.ETX).
# --> 167     child.sendline(chr(3))
#     168     # Read and print any more output the program might produce on its
#     169     # way out.
#     170     try:
#
# UnboundLocalError: local variable 'child' referenced before assignment

# %%
#importa librerias necesarias para ejecucion

import requests

import time

import os

import re

import json

import glob

import threading



#Actualizacion de lista de paquetes

# !sudo apt update &>/dev/null && echo "el apt cache fue actualizado correctamente" || echo "la actualizacion del apt cache fallo, es posible que recibas paquetes obsoletos"

#Asignar archivos al directorio


os.makedirs("/workspaces/codespaces-jupyter/Minecraft-server", exist_ok=True)

os.chdir("/workspaces/codespaces-jupyter/Minecraft-server")

# !ls #lista los archivos del directorio para verificarlos



#Importacion del archivo de configuracion


config_path = "/workspaces/codespaces-jupyter/Minecraft-server/colabconfig.json"

if os.path.isfile(config_path):

    with open(config_path) as config_file:

        colabconfig = json.load(config_file)

else:

    colabconfig = {"server_type": "generic"} # Usar la configura default si no existe

    with open(config_path, 'w') as new_config_file:

        json.dump(colabconfig, new_config_file)



# Instalar OpenJDK


version = colabconfig["server_version"]

if colabconfig["server_version"] < "1.17":

    # !sudo apt-get purge openjdk* > /dev/null 2>&1

    # !sudo apt-get install openjdk-8-jre-headless &>/dev/null and print("OpenJDK 8 instalado!") or print("Error al intalar OpenJDK 8.")

else:

    # !sudo apt-get purge openjdk* > /dev/null 2>&1

    # !sudo apt-get install openjdk-17-jre-headless &>/dev/null and print("OpenJDK 17 instalado!") or print("Error al intalar OpenJDK 17.")


# Chequeo de version de java

java_ver = !java -version 2>&1 | awk -F[\"\.] -v OFS=. 'NR==1{print $2}'

if java_ver[0] == "17":

    print("Estas usando JAVA 17.")

else:

    print("Estas usando una version desactualizada de java. Puedo que Minecraft 1.17+ no funcione.")



#Lista de posibles archivos .jar


jar_list = {'paper': 'server.jar', 'fabric': 'fabric-server-launch.jar', 'generic': 'server.jar', 'forge': 'forge.jar', 'vanilla': 'vanilla.jar', 'snapshot': 'snapshot.jar', 'mohist': "mohist.jar"}

jar_name = jar_list[colabconfig["server_type"]]



# Java arguments.

if colabconfig["server_type"] == "paper":

    server_flags = "-XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true"

else:

    server_flags = "" # No se necesitan banderas para servidores que no sean de paper

#Argumentos JVM

memory_allocation = "-Xms10G -Xmx10G"



# Elige el servicio de tunelacion que desees

# Opciones disponibles: ngrok

tunnel_service = "ngrok"

print("Usando", tunnel_service)


#Condicional de tunelacion del servidor



if tunnel_service == "ngrok":

    # !pip -q install pyngrok #Aqui se instala el ngrok en el servidor

    from pyngrok import conf, ngrok



    # Obten tu token de ngrok

    print("Consigue tu authtoken de https://dashboard.ngrok.com/auth") #Consigue aqui tu token de ngrok, sera dinamico, si quieres que sea estatico, necesitaras la version premiun de ngrok

    import getpass



    # v - - - - - - - TOKEN - - - - - - - v



    authtoken = "2eHVRqC7hNlBqtrJKnss4gV5GRS_6nFsRPofKnttXdbpqrUzQ" # <---- TOKEN NGROK (PON AQUÍ TU TOKEN [TIENE QUE ESTAR ENTRE LAS "COMILLAS"])

    ! ngrok authtoken $authtoken # logeo en ngrok



    #Establecimiento de region de ngrok



    #v - - - - - - - REGIONES DISPONIBLES - - - - - - - v

    # ap - Asia/Pacifico (Singapore)

    # au - Australia (Sydney)

    # eu - Europa (Frankfurt - Alemania)

    # in - India (Mumbai)

    # jp - Japon (Tokyo)

    # sa - America del sur (São Paulo - Brasil)

    # us - Estados unidos (Ohio)

    conf.get_default().region = 'us' # <--- Cambia esto por la region que quieras



    # Conectar a ngrok

    url = ngrok.connect(25565, 'tcp')

    print('La IP de tu servidor es ' + ((str(url).split('"')[1::2])[0]).replace('tcp://', ''))

    #Si obtienes el servicio premiun de ngrok borra las dos lineas de codigo de arriba y quitale el # a estas a continuacion:

    #subdominio = "mi-subdominio"

    #url = ngrok.connect(25565, 'tcp', subdomain=subdominio)

    #print('La IP de tu servidor es ' + url.replace('tcp://', ''))



print('Iniciando servidor...')

def get_users():
    url = 'https://jsonplaceholder.typicode.com/users'
    try:
        response = requests.get(url)
        if response.status_code == 200:
            data = response.json()
            print("Lista de usuarios:")
            for user in data:
                print(f"Nombre: {user['name']}, Email: {user['email']}")
        else:
            print(f"Error al hacer la solicitud. Código de estado: {response.status_code}")
    except requests.RequestException as e:
        print(f"Error de conexión: {e}")

# Función para ejecutar get_users() cada 25 minutos
def repeat_get_users():
    while True:
        get_users()
        time.sleep(600)  # Espera 10 minutos

# Inicia un hilo para ejecutar repeat_get_users() en segundo plano
user_thread = threading.Thread(target=repeat_get_users)
user_thread.start()

if colabconfig["server_type"] == "forge":

    version = colabconfig["server_version"]

    if colabconfig["server_version"] < "1.17":

        oldpathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/forge-{version}-*.jar")

        if oldpathtoforge: # Checa si la lista no esta vacia

            path = oldpathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java $memory_allocation -jar "{path}" nogui

        else:

            print("No se encontro la version de Forge universal.")

    else:

        pathtoforge = glob.glob(f"/workspaces/codespaces-jupyter/Minecraft-server/libraries/net/minecraftforge/forge/{version}-/unix_.txt")

        if pathtoforge: # Checa si la lista no esta vacia

            path = pathtoforge[0] # Obtiene la primera ruta de la lista

            print(path)

            # !java @user_jvm_args.txt "@{path}" "$@"

        else:

            print("No unix_args.txt found.")
else:

    # !java $memory_allocation $server_flags -jar $jar_name nogui



# Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto

while True:
    time.sleep(60)
# Out:
# el apt cache fue actualizado correctamente
# banned-ips.json      eula.txt	    mods	     run.sh
# banned-players.json  forge.jar	    mohist-config    server.properties
# bukkit.yml	     forge.jar.log  mohist.jar	     spigot.yml
# colabconfig.json     help.yml	    ops.json	     user_jvm_args.txt
# commands.yml	     journeymap     patchouli_books  usercache.json
# config		     libraries	    permissions.yml  usernamecache.json
# crash-reports	     logs	    plugins	     whitelist.json
# defaultconfigs	     modernfix	    run.bat	     world
# /bin/bash: -c: line 0: syntax error near unexpected token `('
# /bin/bash: -c: line 0: `sudo apt-get install openjdk-17-jre-headless &>/dev/null and print("OpenJDK 17 instalado!") or print("Error al intalar OpenJDK 17.")'
# Estas usando una version desactualizada de java. Puedo que Minecraft 1.17+ no funcione.
# Usando ngrok
# Consigue tu authtoken de https://dashboard.ngrok.com/auth
# Authtoken saved to configuration file: /home/codespace/.config/ngrok/ngrok.yml
# La IP de tu servidor es 0.tcp.ngrok.io:18478
# Iniciando servidor...
# Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
#
#  ███╗   ███╗  ██████╗  ██╗  ██╗ ██╗ ███████╗ ████████╗
#  ████╗ ████║ ██╔═══██╗ ██║  ██║ ██║ ██╔════╝ ╚══██╔══╝
#  ██╔████╔██║ ██║   ██║ ███████║ ██║ ███████╗    ██║
#  ██║╚██╔╝██║ ██║   ██║ ██╔══██║ ██║ ╚════██║    ██║
#  ██║ ╚═╝ ██║ ╚██████╔╝ ██║  ██║ ██║ ███████║    ██║
#  ╚═╝     ╚═╝  ╚═════╝  ╚═╝  ╚═╝ ╚═╝ ╚══════╝    ╚═╝
#
#
# Thanks for using Mohist - 1.20.1-580, Java(21.0.2) 65.0 PID: 2633
#
# Update in check...
# If you don't want to enable update check, set check_update in mohist-config/mohist.yml to false
# The latest Mohist version is 1.20.1-643 but you have 1.20.1-580. The latest version has been built on 2024-04-01 01:15:46. You should update to fix recent bugs!
# Checking libraries, please wait...
# All libraries are nice :)!
# Searching incompatible mods...
# [01:59:32 INFO]: ModLauncher running: args [--launchTarget, forgeserver, --fml.forgeVersion, 47.2.20, --fml.mcVersion, 1.20.1, --fml.forgeGroup, net.minecraftforge, --fml.mcpVersion, 20230612.114412, nogui]
# [01:59:32 INFO]: ModLauncher 10.0.9+10.0.9+main.dcd20f30 starting: java version 21.0.2 by Microsoft; OS Linux arch amd64 version 6.2.0-1019-azure
# t=2024-04-02T01:59:33+0000 lvl=warn msg="failed to open private leg" id=4b47dba7643f typ=proxy privaddr=localhost:25565 err="dial tcp [::1]:25565: connect: connection refused"
# [01:59:38 INFO]: ImmediateWindowProvider not loading because launch target is forgeserver
# [01:59:38 INFO]: SpongePowered MIXIN Subsystem Version=0.8.5 Source=union:/workspaces/codespaces-jupyter/Minecraft-server/libraries/org/spongepowered/mixin/0.8.5/mixin-0.8.5.jar%23111!/ Service=ModLauncher Env=SERVER
# [01:59:39 WARN]: Attempted to select two dependency jars from JarJar which have the same identification: Mod File:  and Mod File: . Using Mod File:
# [01:59:39 WARN]: Attempted to select a dependency jar for JarJar which was passed in as source: geckolib. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/geckolib-forge-1.20.1-4.4.2.jar
# [01:59:39 WARN]: Attempted to select a dependency jar for JarJar which was passed in as source: expandability. Using Mod File: /workspaces/codespaces-jupyter/Minecraft-server/mods/expandability-9.0.0.jar
# [01:59:39 INFO]: Found 14 dependencies adding them to mods collection
# [01:59:42 ERROR]: Mixin config dynamiclightsreforged.mixins.json does not specify "minVersion" property
# [01:59:42 INFO]: Compatibility level set to JAVA_17
# [01:59:42 ERROR]: Mixin config azurelib.mixins.json does not specify "minVersion" property
# [01:59:42 ERROR]: Mixin config azurelib.forge.mixins.json does not specify "minVersion" property
# [01:59:42 INFO]: Successfully loaded Mixin Connector [com.sonicether.soundphysics.MixinConnector]
# [01:59:42 INFO]: Launching target 'forgeserver' with arguments [nogui]
# [01:59:42 INFO]: Loaded Saturn config file with 4 configurable options
# [01:59:43 INFO]: Loaded configuration file for ModernFix 5.15.0+mc1.20.1: 77 options available, 1 override(s) found
# [01:59:43 WARN]: Option 'mixin.perf.thread_priorities' overriden (by mods [smoothboot]) to 'false'
# [01:59:43 INFO]: Applying Nashorn fix
# [01:59:43 INFO]: Applied Forge config corruption patch
# [01:59:43 WARN]: Reference map 'jeed-forge-refmap.json' for jeed.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:59:43 INFO]: OptiFine was NOT detected.
# [01:59:43 INFO]: OptiFabric was NOT detected.
# [01:59:43 INFO]: Loaded configuration file for Embeddium: 206 options available, 0 override(s) found
# [01:59:43 WARN]: Reference map 'bno.refmap.json' for bno.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:59:43 WARN]: Reference map 'bno.refmap.json' for bno.forge.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:59:43 WARN]: Reference map '${refmap_target}refmap.json' for corgilib.forge.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:59:43 INFO]: Loaded configuration file for Canary: 116 options available, 0 override(s) found
# [01:59:43 INFO]: Loaded configuration file for Sodium Extra: 34 options available, 0 override(s) found
# [01:59:43 INFO]: Loading 162 mods:
# 	- advancednetherite 2.0.2
# 	- alexscaves 1.1.4
# 	- alexsdelight 1.5
# 	- alexsmobs 1.22.7
# 	- ambientsounds 5.3.9
# 	- amplifiednether 1.2.4
# 	- animalistic_a 1.2.2
# 	- appleskin 2.5.1+mc1.20.1
# 	- aquaculture 2.5.1
# 	- aquamirae 6.API15
# 	- architectury 9.2.14
# 	- ars_nouveau 4.9.0
# 	- artifacts 9.3.0
# 	- astemirlib 1.25
# 	- athena 3.1.1
# 	- attributefix 21.0.4
# 	- awesomedungeon 3.2.0
# 	- awesomedungeonend 3.1.1
# 	- awesomedungeonnether 3.1.1
# 	- awesomedungeonocean 3.3.0
# 	- azurelib 2.0.20
# 	- balm 7.2.2
# 	- better_fishing_rods 1.0.0
# 	- betterfog 1.0.0
# 	- betterfpsdist 1.20.1-4.3
# 	- betterthirdperson 1.9.0
# 	- bettervillage 3.1.0
# 	- biomesoplenty 18.0.0.598
# 	- bno 9.1.1
# 	- bookshelf 20.1.9
# 	- born_in_chaos_v1 1.0.0
# 	- bountiful 6.0.3+1.20.1
# 	- caelus 3.1.0+1.20
# 	- campfirespawnandtweaks 3.6
# 	- canary 0.3.3
# 	- carryon 2.1.2.7
# 	- catalogue 1.8.0
# 	- cgm 1.4.12+Forge+1.20.1}
# 	- charmofundying 6.4.5+1.20.1
# 	- chipped 3.0.4
# 	- chococraft 0.9.10
# 	- chunky 1.3.136
# 	- citadel 2.5.4
# 	- clientcrafting 1.20.1-1.8
# 	- cloth_config 11.1.118
# 	- clumps 12.0.0.3
# 	- cofh_core 11.0.0
# 	- collective 7.36
# 	- colytra 6.2.2+1.20.1
# 	- comforts 6.3.5+1.20.1
# 	- connectivity 1.20.1-5.4
# 	- corgilib 4.0.1.0
# 	- corpse 1.20.1-1.0.12
# 	- cosmeticarmorreworked 1.20.1-v1a
# 	- creativecore 2.11.24
# 	- creeperoverhaul 3.0.2
# 	- cupboard 1.20.1-2.5
# 	- curios 5.7.0+1.20.1
# 	- dungeoncrawl 2.3.14
# 	- dungeons_arise 2.1.58-1.20.x
# 	- dynamiclights 1.20.1.2
# 	- dynamiclightsreforged 1.20.1_v1.6.0
# 	- easyanvils 8.0.2
# 	- easymagic 8.0.1
# 	- editenchanting 1.1.2
# 	- elevatorid 1.20.1-lex-1.9
# 	- embeddium 0.3.7+mc1.20.1
# 	- embeddium_extra 0.5.4.1+mc1.20.1-build.117
# 	- enchdesc 17.0.14
# 	- endermanoverhaul 1.0.4
# 	- enemyexpansion 2.1.0
# 	- enhancedcelestials 5.0.0.2
# 	- ensorcellation 5.0.0
# 	- entityculling 1.6.2
# 	- epicsamurai 0.0.39-1.20.1-neo
# 	- expandability 9.0.0
# 	- experiencebugfix 46.2.2
# 	- explorify 1.3.0-mc1.20
# 	- fallingleaves 2.1.0
# 	- farmersdelight 1.20.1-1.2.4
# 	- farsight_view 1.20.1-3.6
# 	- fastload 3.4.0
# 	- ferritecore 6.0.1
# 	- forge 47.2.20
# 	- fpsreducer 1.20-2.5
# 	- framework 0.6.26
# 	- gamma_beasts 1.0.1
# 	- geckolib 4.4.2
# 	- gemsnjewels 0.1.0
# 	- goblintraders 1.9.3
# 	- gpumemleakfix 1.20.1-1.8
# 	- guardvillagers 1.20.1-1.6.4
# 	- healingcampfire 5.3
# 	- horsecombatcontrols 1.20.1-1.0.1
# 	- iceandfire 2.1.13-1.20.1-beta-4
# 	- immediatelyfast 1.2.10+1.20.4
# 	- immersive_armors 1.6.1+1.20.1
# 	- incendium 5.3.4
# 	- inventoryprofilesnext 1.10.9
# 	- ironchest 1.20.1-14.4.4
# 	- ironfurnaces 4.1.5
# 	- itemproductionlib 1.0.2a
# 	- jade 11.8.0
# 	- jeed 1.20-2.1.7
# 	- jei 15.3.0.4
# 	- jeresources 1.4.0.247
# 	- journeymap 5.9.18p1
# 	- justenoughprofessions 3.0.1
# 	- kambrik 6.1.1+1.20.1
# 	- kotlinforforge 4.10.0
# 	- krypton 0.2.3
# 	- libipn 4.0.1
# 	- libraryferret 4.0.0
# 	- magistuarmory 8.11
# 	- maxhealthfix 12.0.2
# 	- minecraft 1.20.1
# 	- mininggadgets 1.15.6
# 	- mixinextras 0.2.0-beta.8
# 	- moblassos 8.0.1
# 	- modernfix 5.15.0+mc1.20.1
# 	- mohist 1.20.1
# 	- mr_dungeons_andtaverns 3.0.3
# 	- nullscape 1.2.4
# 	- nyctophobia 1.6
# 	- nyfsspiders 2.1.1
# 	- obscure_api 15
# 	- onlyhammers 1.20.1-0.5
# 	- paraglider 20.1.3
# 	- patchouli 1.20.1-84-FORGE
# 	- pipez 1.20.1-1.2.5
# 	- playerrevive 2.0.24
# 	- polymorph 0.49.2+1.20.1
# 	- puzzlesaccessapi 8.0.7
# 	- puzzleslib 8.1.17
# 	- reap 1.20.1-1.0.2
# 	- reeses_sodium_options 1.0.4
# 	- regions_unexplored 0.5.5
# 	- reliquary 1.20.1-2.0.36.1199
# 	- repurposed_structures 7.1.13+1.20.1-forge
# 	- resourcefulconfig 2.1.2
# 	- resourcefullib 2.1.20
# 	- responsiveshields 2.3
# 	- rpgsmw 7.91.20.1
# 	- rubidium 0.7.1
# 	- saturn 0.1.3
# 	- securitycraft 1.9.8
# 	- skilltree 0.6.11
# 	- smoothboot 0.0.3
# 	- sons_of_sins 2.1.6
# 	- sophisticatedbackpacks 3.20.2.1022
# 	- sophisticatedcore 0.6.7.561
# 	- sound_physics_remastered 1.20.1-1.1.2
# 	- spark 1.10.53
# 	- spectrelib 0.13.15+1.20.1
# 	- storagedrawers 12.0.3
# 	- terrablender 3.0.1.4
# 	- terralith 2.4.11
# 	- textrues_embeddium_options 0.1.5+mc1.20.1
# 	- torchmaster 20.1.5
# 	- visualworkbench 8.0.0
# 	- vtweaks 4.0.13.fix1
# 	- waystones 14.1.3
# [01:59:43 WARN]: Reference map 'moblassos.refmap.json' for moblassos.common.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:59:43 WARN]: Reference map 'Aquamirae.refmap.json' for aquamirae.mixins.json could not be read. If this is a development environment you can ignore this message
# [01:59:45 WARN]: Error loading class: xyz/przemyk/simpleplanes/upgrades/shooter/ShooterUpgrade (java.lang.ClassNotFoundException: xyz.przemyk.simpleplanes.upgrades.shooter.ShooterUpgrade)
# [01:59:45 WARN]: @Mixin target xyz.przemyk.simpleplanes.upgrades.shooter.ShooterUpgrade was not found cgm.mixins.json:common.simpleplanes.ShooterUpgradeMixin
# [01:59:45 ERROR]: Attempted to load class net/minecraft/client/multiplayer/MultiPlayerGameMode for invalid dist DEDICATED_SERVER
# [01:59:45 WARN]: Error loading class: net/minecraft/client/multiplayer/MultiPlayerGameMode (java.lang.RuntimeException: Attempted to load class net/minecraft/client/multiplayer/MultiPlayerGameMode for invalid dist DEDICATED_SERVER)
# [01:59:45 WARN]: @Mixin target net.minecraft.client.multiplayer.MultiPlayerGameMode was not found mixins.cofhcore.json:MultiPlayerGameModeMixin
# [01:59:45 WARN]: Error loading class: tfar/davespotioneering/blockentity/AdvancedBrewingStandBlockEntity (java.lang.ClassNotFoundException: tfar.davespotioneering.blockentity.AdvancedBrewingStandBlockEntity)
# [01:59:45 WARN]: @Mixin target tfar.davespotioneering.blockentity.AdvancedBrewingStandBlockEntity was not found itemproductionlib.mixins.json:davespotioneering/AdvancedBrewingStandBlockEntityMixin
# [01:59:45 WARN]: Error loading class: dev/shadowsoffire/apotheosis/ench/table/ApothEnchantmentMenu (java.lang.ClassNotFoundException: dev.shadowsoffire.apotheosis.ench.table.ApothEnchantmentMenu)
# [01:59:45 WARN]: @Mixin target dev.shadowsoffire.apotheosis.ench.table.ApothEnchantmentMenu was not found skilltree.mixins.json:apotheosis/ApothEnchantContainerMixin
# [01:59:45 WARN]: Error loading class: dev/shadowsoffire/apotheosis/adventure/affix/socket/SocketingRecipe (java.lang.ClassNotFoundException: dev.shadowsoffire.apotheosis.adventure.affix.socket.SocketingRecipe)
# [01:59:45 WARN]: @Mixin target dev.shadowsoffire.apotheosis.adventure.affix.socket.SocketingRecipe was not found skilltree.mixins.json:apotheosis/SocketingRecipeMixin
# [01:59:45 WARN]: Error loading class: dev/shadowsoffire/apotheosis/adventure/affix/socket/gem/bonus/AttributeBonus (java.lang.ClassNotFoundException: dev.shadowsoffire.apotheosis.adventure.affix.socket.gem.bonus.AttributeBonus)
# [01:59:45 WARN]: @Mixin target dev.shadowsoffire.apotheosis.adventure.affix.socket.gem.bonus.AttributeBonus was not found skilltree.mixins.json:apotheosis/AttributeBonusMixin
# [01:59:45 WARN]: Error loading class: dev/shadowsoffire/apotheosis/adventure/affix/socket/gem/bonus/EnchantmentBonus (java.lang.ClassNotFoundException: dev.shadowsoffire.apotheosis.adventure.affix.socket.gem.bonus.EnchantmentBonus)
# [01:59:45 WARN]: @Mixin target dev.shadowsoffire.apotheosis.adventure.affix.socket.gem.bonus.EnchantmentBonus was not found skilltree.mixins.json:apotheosis/EnchantmentBonusMixin
# [01:59:45 WARN]: Error loading class: com/mojang/blaze3d/audio/Channel (java.lang.ClassNotFoundException: com.mojang.blaze3d.audio.Channel)
# [01:59:45 WARN]: @Mixin target com.mojang.blaze3d.audio.Channel was not found assets/sound_physics_remastered/sound_physics_remastered.mixins.json:ChannelAccessor
# [01:59:46 INFO]: Initializing MixinExtras via com.llamalad7.mixinextras.service.MixinExtrasServiceImpl(version=0.3.5).
# [01:59:47 INFO]: ModernFix reached bootstrap stage (24.84 s after launch)
# [01:59:47 WARN]: @Final field delegatesByName:Ljava/util/Map; in modernfix-forge.mixins.json:perf.forge_registry_alloc.ForgeRegistryMixin should be final
# [01:59:47 WARN]: @Final field delegatesByValue:Ljava/util/Map; in modernfix-forge.mixins.json:perf.forge_registry_alloc.ForgeRegistryMixin should be final
# [01:59:47 INFO]: Injecting BlockStateBase cache population hook into getNeighborPathNodeType from com.abdelaziz.canary.mixin.ai.pathing.BlockStateBaseMixin
# [01:59:47 INFO]: Injecting BlockStateBase cache population hook into getPathNodeType from com.abdelaziz.canary.mixin.ai.pathing.BlockStateBaseMixin
# [01:59:49 INFO]: Vanilla bootstrap took 2043 milliseconds
# [01:59:51 WARN]: @Final field f_26027_:Lnet/minecraft/world/entity/ai/targeting/TargetingConditions; in guardvillagers.mixins.json:DefendVillageGoalGolemMixin should be final
# [01:59:52 WARN]: Static binding violation: PRIVATE @Overwrite method m_47505_ in modernfix-common.mixins.json:perf.remove_biome_temperature_cache.BiomeMixin cannot reduce visibiliy of PUBLIC target method, visibility will be upgraded.
# [01:59:52 WARN]: Method overwrite conflict for m_47505_ in modernfix-common.mixins.json:perf.remove_biome_temperature_cache.BiomeMixin, previously written by com.abdelaziz.saturn.mixin.leaks.biome_temperature_cache.BiomeMixin. Skipping method.
# [01:59:57 INFO]: [LambDynLights] Initializing Dynamic Lights Reforged...
# [01:59:57 INFO]: Constructing common components for easyanvils:main
# [01:59:57 INFO]: Loaded maxhealthfix for Forge.
# [01:59:57 INFO]: Fixing MC-151457. Crafting remainder for minecraft:pufferfish_bucket is now minecraft:bucket.
# [01:59:57 INFO]: Fixing MC-151457. Crafting remainder for minecraft:salmon_bucket is now minecraft:bucket.
# [01:59:57 INFO]: Fixing MC-151457. Crafting remainder for minecraft:cod_bucket is now minecraft:bucket.
# [01:59:57 INFO]: Fixing MC-151457. Crafting remainder for minecraft:tropical_fish_bucket is now minecraft:bucket.
# [01:59:57 INFO]: Fixing MC-151457. Crafting remainder for minecraft:axolotl_bucket is now minecraft:bucket.
# [01:59:57 INFO]: Fixing MC-151457. Crafting remainder for minecraft:powder_snow_bucket is now minecraft:bucket.
# [01:59:57 INFO]: Fixing MC-151457. Crafting remainder for minecraft:tadpole_bucket is now minecraft:bucket.
# Service loaders found: [io.ejekta.kambrik.bridge.KambrikSharedApiForge@76f8a1ef]
# [01:59:58 ERROR]: Attempted to load class net/minecraft/client/Minecraft for invalid dist DEDICATED_SERVER
# [01:59:58 ERROR]: Failed to update fingerprint
# java.lang.NoClassDefFoundError: net/minecraft/client/Minecraft
# 	at me.jellysquid.mods.sodium.client.data.fingerprint.FingerprintMeasure.create(FingerprintMeasure.java:19) ~[embeddium-0.3.7+mc1.20.1.jar%23419!/:?]
# 	at me.jellysquid.mods.sodium.client.SodiumClientMod.updateFingerprint(SodiumClientMod.java:100) ~[embeddium-0.3.7+mc1.20.1.jar%23419!/:?]
# 	at me.jellysquid.mods.sodium.client.SodiumClientMod.<init>(SodiumClientMod.java:41) ~[embeddium-0.3.7+mc1.20.1.jar%23419!/:?]
# 	at jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:62) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:502) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstance(Constructor.java:486) ~[?:?]
# 	at net.minecraftforge.fml.javafmlmod.FMLModContainer.constructMod(FMLModContainer.java:76) ~[javafmllanguage-1.20.1-47.2.20.jar%23508!/:?]
# 	at net.minecraftforge.fml.ModContainer.lambda$buildTransitionHandler$10(ModContainer.java:123) ~[fmlcore-1.20.1-47.2.20.jar%23507!/:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.run(CompletableFuture.java:1804) [?:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.exec(CompletableFuture.java:1796) [?:?]
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) [?:?]
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) [?:?]
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) [?:?]
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) [?:?]
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) [?:?]
# Caused by: java.lang.ClassNotFoundException: net.minecraft.client.Minecraft
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:157) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	... 15 more
# experiencebugfix: Registering Mod.
# [01:59:59 INFO]: Loading Collective version 7.36.
# [01:59:59 INFO]: Initializing Update Checker...
# [01:59:59 INFO]: Starting Update Check...
# [01:59:59 INFO]: Hello world!
# [01:59:59 INFO]: Update Check done!
# [01:59:59 INFO]: Iron Furnaces is up to date!
# [01:59:59 INFO]: Loaded config for: cupboard.json
# [01:59:59 INFO]: [Inventory Profiles Next] Inventory Profiles Next - init in Kotlin
# [01:59:59 INFO]: Constructing common components for easymagic:main
# [01:59:59 INFO]: Registering C2S receiver with id architectury:sync_ids
# [01:59:59 INFO]: Constructing common components for visualworkbench:main
# [01:59:59 INFO]: Initialize mod Library Ferret
# [01:59:59 INFO]: Initialized mod Library Ferret
# [01:59:59 ERROR]: Could not find parent net/minecraft/client/renderer/entity/layers/RenderLayer for class com/obscuria/obscureapi/client/renderer/PatreonLayer in classloader cpw.mods.modlauncher.TransformingClassLoader@4ae49387 on thread Thread[#40,modloading-worker-0,5,main]
# [01:59:59 ERROR]: An error occurred building event handler
# java.lang.ClassNotFoundException: net.minecraft.client.renderer.entity.layers.RenderLayer
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:157) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.buildEvents(EventSubclassTransformer.java:97) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventSubclassTransformer.transform(EventSubclassTransformer.java:48) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.EventBusEngine.processClass(EventBusEngine.java:26) ~[eventbus-6.0.5.jar:?]
# 	at net.minecraftforge.eventbus.service.ModLauncherService.processClassWithFlags(ModLauncherService.java:32) ~[eventbus-6.0.5.jar:6.0.5+0+master.c510e2cc]
# 	at cpw.mods.modlauncher.LaunchPluginHandler.offerClassNodeToPlugins(LaunchPluginHandler.java:88) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.ClassTransformer.transform(ClassTransformer.java:120) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.modlauncher.TransformingClassLoader.maybeTransformClassBytes(TransformingClassLoader.java:50) ~[modlauncher-10.0.9.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.readerToClass(ModuleClassLoader.java:121) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.lambda$findClass$15(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadFromModule(ModuleClassLoader.java:267) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.findClass(ModuleClassLoader.java:257) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at cpw.mods.cl.ModuleClassLoader.loadClass(ModuleClassLoader.java:144) ~[securejarhandler-mohist-2.1.11.jar:?]
# 	at java.lang.ClassLoader.loadClass(ClassLoader.java:526) ~[?:?]
# 	at java.lang.ClassLoader.defineClass0(Native Method) ~[?:?]
# 	at java.lang.System$2.defineClass(System.java:2394) ~[?:?]
# 	at java.lang.invoke.MethodHandles$Lookup$ClassDefiner.defineClass(MethodHandles.java:2505) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.generateInnerClass(InnerClassLambdaMetafactory.java:361) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.spinInnerClass(InnerClassLambdaMetafactory.java:286) ~[?:?]
# 	at java.lang.invoke.InnerClassLambdaMetafactory.buildCallSite(InnerClassLambdaMetafactory.java:221) ~[?:?]
# 	at java.lang.invoke.LambdaMetafactory.metafactory(LambdaMetafactory.java:341) ~[?:?]
# 	at java.lang.invoke.BootstrapMethodInvoker.invoke(BootstrapMethodInvoker.java:134) ~[?:?]
# 	at java.lang.invoke.CallSite.makeSite(CallSite.java:316) ~[?:?]
# 	at java.lang.invoke.MethodHandleNatives.linkCallSiteImpl(MethodHandleNatives.java:274) ~[?:?]
# 	at java.lang.invoke.MethodHandleNatives.linkCallSite(MethodHandleNatives.java:264) ~[?:?]
# 	at com.obscuria.obscureapi.client.renderer.PatreonLayer$Mode.<clinit>(PatreonLayer.java:55) ~[obscure_api-15.jar%23473!/:com.obscuria]
# 	at com.obscuria.obscureapi.ObscureAPIConfig$Client.<clinit>(ObscureAPIConfig.java:28) ~[obscure_api-15.jar%23473!/:com.obscuria]
# 	at com.obscuria.obscureapi.ObscureAPIConfig.register(ObscureAPIConfig.java:46) ~[obscure_api-15.jar%23473!/:com.obscuria]
# 	at com.obscuria.obscureapi.ObscureAPI.<init>(ObscureAPI.java:69) ~[obscure_api-15.jar%23473!/:com.obscuria]
# 	at jdk.internal.reflect.DirectConstructorHandleAccessor.newInstance(DirectConstructorHandleAccessor.java:62) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstanceWithCaller(Constructor.java:502) ~[?:?]
# 	at java.lang.reflect.Constructor.newInstance(Constructor.java:486) ~[?:?]
# 	at net.minecraftforge.fml.javafmlmod.FMLModContainer.constructMod(FMLModContainer.java:76) ~[javafmllanguage-1.20.1-47.2.20.jar%23508!/:?]
# 	at net.minecraftforge.fml.ModContainer.lambda$buildTransitionHandler$10(ModContainer.java:123) ~[fmlcore-1.20.1-47.2.20.jar%23507!/:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.run(CompletableFuture.java:1804) [?:?]
# 	at java.util.concurrent.CompletableFuture$AsyncRun.exec(CompletableFuture.java:1796) [?:?]
# 	at java.util.concurrent.ForkJoinTask.doExec(ForkJoinTask.java:387) [?:?]
# 	at java.util.concurrent.ForkJoinPool$WorkQueue.topLevelExec(ForkJoinPool.java:1312) [?:?]
# 	at java.util.concurrent.ForkJoinPool.scan(ForkJoinPool.java:1843) [?:?]
# 	at java.util.concurrent.ForkJoinPool.runWorker(ForkJoinPool.java:1808) [?:?]
# 	at java.util.concurrent.ForkJoinWorkerThread.run(ForkJoinWorkerThread.java:188) [?:?]
# [01:59:59 ERROR]: Attempted to load class com/obscuria/obscureapi/client/renderer/PatreonLayer for invalid dist DEDICATED_SERVER
# [01:59:59 WARN]: Falling Leaves is a client only mod and should be removed from the mods list
# [01:59:59 INFO]: Registering C2S receiver with id artifacts:networking_channel/42a7ad70b1cc371599a0eff744096b8a
# [01:59:59 INFO]: Registering C2S receiver with id artifacts:networking_channel/74a5e841822a3a87854ae896a33430d6
# [01:59:59 INFO]: Registering C2S receiver with id artifacts:networking_channel/eb3d1e2748533430848cadf0f37c7e9c
# [01:59:59 INFO]: Registering C2S receiver with id artifacts:networking_channel/91c8520f19f93b3e8b6a727568e194ab
# [01:59:59 INFO]: Registering C2S receiver with id artifacts:networking_channel/8c2784d778293fd482ed84b8aa5fedb9
# [01:59:59 INFO]: Here we go! Launching Dungeon Crawl 2.3.14...
# [01:59:59 INFO]: Registering C2S receiver with id magistuarmory:packet_long_reach_attack
# [01:59:59 INFO]: Registering C2S receiver with id magistuarmory:packet_lance_collision
# [02:00:00 INFO]: Registered azurelib config for auto-sync function
# [02:00:00 INFO]: Mohist mod loading.....
# [02:00:00 INFO]: EventDispatcherRegistry initialized
# [02:00:00 INFO]: Forge mod loading, version 47.2.20, for MC 1.20.1 with MCP 20230612.114412
# [02:00:00 INFO]: MinecraftForge v47.2.20 Initialized
# [02:00:00 INFO]: NeoForge v47.2.20 Initialized
# [02:00:00 INFO]: [libIPN] libIPN - init in Kotlin
# [02:00:01 INFO]: Kotlin For Forge Enabled!
# [02:00:01 INFO]: Constructing common components for puzzleslib:main
# [02:00:01 INFO]: ExpandAbility here, who dis?
# [02:00:01 INFO]: Constructing common components for moblassos:main
# [02:00:01 INFO]: Bypassed Mojang DFU
# [02:00:01 INFO]: Instantiating Mojang DFU
# [02:00:03 INFO]: BNO - Block Registered
# [02:00:04 INFO]: BNO - Block Items Registered
# [02:00:06 INFO]: Connectivity initialized
# [02:00:06 INFO]: gpumemleakfix mod initialized
# [02:00:06 INFO]: Reloading reverb parameters
# [02:00:07 INFO]: Common Setup
# [02:00:07 INFO]: farsight_view mod initialized
# [02:00:07 INFO]: Compression will use libdeflate (Linux x86_64), encryption will use OpenSSL 1.1.x (Linux x86_64)
# [02:00:07 INFO]: Registered region minecraft:overworld to index 0 for type OVERWORLD
# [02:00:07 INFO]: Registered region minecraft:nether to index 0 for type NETHER
# [02:00:07 INFO]: Registered region regions_unexplored:primary to index 1 for type OVERWORLD
# [02:00:07 INFO]: Registered region regions_unexplored:secondary to index 2 for type OVERWORLD
# [02:00:07 INFO]: Registered region regions_unexplored:nether to index 1 for type NETHER
# [02:00:07 INFO]: New compacting rule 4 clay_ball = 1 clay
# [02:00:07 INFO]: New compacting rule 4 snowball = 1 snow_block
# [02:00:07 INFO]: New compacting rule 4 glowstone_dust = 1 glowstone
# [02:00:07 INFO]: New compacting rule 4 brick = 1 bricks
# [02:00:07 INFO]: New compacting rule 4 nether_brick = 1 nether_bricks
# [02:00:07 INFO]: New compacting rule 9 nether_wart = 1 nether_wart_block
# [02:00:07 INFO]: New compacting rule 4 quartz = 1 quartz_block
# [02:00:07 INFO]: New compacting rule 9 melon_slice = 1 melon
# [02:00:07 INFO]: New compacting rule 4 sand = 1 sandstone
# [02:00:07 INFO]: New compacting rule 4 red_sand = 1 red_sandstone
# [02:00:07 INFO]: Initialized enhancedcelestials network!
# [02:00:07 INFO]: Initializing network...
# [02:00:07 INFO]: Initialized network!
# [02:00:07 INFO]: New compacting rule 4 clay_ball = 1 clay
# [02:00:07 INFO]: Registered region nyctophobia:biome_provider to index 3 for type OVERWORLD
# [02:00:07 INFO]: Please use /mfsrc to reload any changed mod config files
# [02:00:07 INFO]: Registered synced data key cgm:aiming for minecraft:player
# [02:00:07 INFO]: Registered synced data key cgm:reloading for minecraft:player
# [02:00:07 INFO]: Registered synced data key cgm:shooting for minecraft:player
# [02:00:07 INFO]: Initializing Packet Registries
# [02:00:07 INFO]: Registered region biomesoplenty:overworld_primary to index 4 for type OVERWORLD
# [02:00:07 INFO]: Registered region biomesoplenty:overworld_secondary to index 5 for type OVERWORLD
# [02:00:07 INFO]: Registered region biomesoplenty:overworld_rare to index 6 for type OVERWORLD
# [02:00:07 INFO]: Registered region biomesoplenty:nether_common to index 2 for type NETHER
# [02:00:07 INFO]: Registered region biomesoplenty:nether_rare to index 3 for type NETHER
# [02:00:07 INFO]: Registered region ars_nouveau:overworld to index 7 for type OVERWORLD
# [02:00:07 INFO]: Applying mega torch entity block list overrides...
# [02:00:07 INFO]: Applying dread lamp entity block list overrides...
# [02:00:07 INFO]: Loaded values for 43 compatible attributes.
# [02:00:07 INFO]: Loaded 43 values from config.
# [02:00:07 INFO]: Saving config file. 43 entries.
# [02:00:07 INFO]: Applying changes for 43 attributes.
# [02:00:07 INFO]: Start loading plugin at de.maxhenkel.corpse.integration.waila.PluginCorpse
# [02:00:07 INFO]: Start loading plugin at net.blay09.mods.waystones.compat.JadeIntegration
# [02:00:07 INFO]: Start loading plugin at com.hollingsworth.arsnouveau.client.waila.WailaArsNouveauPlugin
# [02:00:07 INFO]: Start loading plugin at snownee.jade.addon.vanilla.VanillaPlugin
# [02:00:07 INFO]: Start loading plugin at snownee.jade.addon.universal.UniversalPlugin
# [02:00:07 INFO]: Start loading plugin at snownee.jade.addon.core.CorePlugin
# [02:00:07 INFO]: Start loading plugin at de.maxhenkel.pipez.integration.waila.PluginPipes
# [02:00:07 INFO]: Start loading plugin at reliquary.compat.jade.JadeCompat
# [02:00:07 INFO]: Start loading plugin at net.geforcemods.securitycraft.compat.waila.JadeDataProvider
# [02:00:07 INFO]: Start loading plugin at com.jaquadro.minecraft.storagedrawers.integration.Waila
# [02:00:08 INFO]: Environment: authHost='https://authserver.mojang.com', accountsHost='https://api.mojang.com', sessionHost='https://sessionserver.mojang.com', servicesHost='https://api.minecraftservices.com', name='PROD'
# [02:00:10 INFO]: Structure placement for `awesomedungeon:abandoned_oak_palace/start_pool`: { spacing: 50, separation: 25, salt: 1694767080, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeonend:aws_all_end_structures/start_pool`: { spacing: 20, separation: 15, salt: 49082056, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeon:better_default_jungle_temple/start_pool`: { spacing: 50, separation: 25, salt: 1654787080, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeonocean:brigantine/start_pool`: { spacing: 50, separation: 25, salt: 254835856, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeon:desert_temple_husk/start_pool`: { spacing: 50, separation: 25, salt: 1394767080, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeonocean:frigate_large/start_pool`: { spacing: 50, separation: 25, salt: 35482856, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeonocean:frigate_medium/start_pool`: { spacing: 50, separation: 25, salt: 45482856, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeon:jungle_giant_tree/start_pool`: { spacing: 50, separation: 25, salt: 1494763380, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeon:mushroom_abandonned/start_pool`: { spacing: 50, separation: 25, salt: 1494227080, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeonnether:nth_absi_palace/start_pool`: { spacing: 50, separation: 25, salt: 19482856, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeonnether:nth_accum_quad/start_pool`: { spacing: 50, separation: 25, salt: 28482856, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeonnether:nth_blaze_tower/start_pool`: { spacing: 50, separation: 25, salt: 37482856, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeonnether:nth_center_square/start_pool`: { spacing: 50, separation: 25, salt: 46482856, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeonnether:nth_giant_crimson_tree/start_pool`: { spacing: 50, separation: 25, salt: 55482856, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeonnether:nth_obsi_house/start_pool`: { spacing: 50, separation: 25, salt: 64482856, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeonocean:ocean_cage/start_pool`: { spacing: 50, separation: 25, salt: 40842806, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeonocean:ocean_quad/start_pool`: { spacing: 50, separation: 25, salt: 254835856, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeonocean:ocean_ruin_pillager/start_pool`: { spacing: 50, separation: 25, salt: 254145856, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeonocean:ocean_ruin_vanilla_temple/start_pool`: { spacing: 50, separation: 25, salt: 25482856, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeonocean:ocean_temple_quad/start_pool`: { spacing: 50, separation: 25, salt: 35482856, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeonocean:ocean_the_column_temple/start_pool`: { spacing: 50, separation: 25, salt: 15482856, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeonocean:ocean_warn_temple/start_pool`: { spacing: 50, separation: 25, salt: 45482856, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeon:swamp_big_temple/start_pool`: { spacing: 50, separation: 25, salt: 1594763280, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeon:the_usine/start_pool`: { spacing: 50, separation: 25, salt: 1694767078, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeon:t_z_tower/start_pool`: { spacing: 50, separation: 25, salt: 1794767078, useValueFromConfiguration: true}
# [02:00:10 INFO]: Structure placement for `awesomedungeon:witch_castle/start_pool`: { spacing: 50, separation: 25, salt: 1894776078, useValueFromConfiguration: true}
# [02:00:12 INFO]: Adding serverside commands..
# [02:00:12 INFO]: Adding datapack listener capsid_recipes
# [02:00:14 WARN]: Found loot table element validation problem in {loot_tables:sons_of_sins:entities/walking_bed}.pools[0].entries[0].functions[1]: Parameters [<parameter minecraft:tool>] are not provided in this context
# [02:00:14 WARN]: Found loot table element validation problem in {loot_tables:sons_of_sins:entities/blud}.pools[0].entries[0].functions[1]: Parameters [<parameter minecraft:tool>] are not provided in this context
# [02:00:14 WARN]: Found loot table element validation problem in {loot_tables:sons_of_sins:entities/prowler}.pools[0].entries[0].functions[1]: Parameters [<parameter minecraft:tool>] are not provided in this context
# [02:00:14 WARN]: Found loot table element validation problem in {loot_tables:sons_of_sins:entities/butcher}.pools[0].entries[0].functions[1]: Parameters [<parameter minecraft:tool>] are not provided in this context
# [02:00:14 INFO]: Skipping loading recipe reliquary:squid_beak as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:sculk_samruai_boots_smithing as it's serializer returned null
# [02:00:14 ERROR]: Parsing error loading recipe epicsamurai:mask_quartz_samurai_helmet: com.google.gson.JsonSyntaxException: Unknown item 'epicsamurai:mask_quartz_samurai_helmet'
# [02:00:14 ERROR]: Parsing error loading recipe rpgsmw:bk: com.google.gson.JsonSyntaxException: Unknown item 'rpgsmw:deleted_mod_element'
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:brass_samruai_helmet_mechanical_crafting as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:brass_samruai_chestplate_mechanical_crafting as it's serializer returned null
# [02:00:14 ERROR]: Parsing error loading recipe rpgsmw:pb: com.google.gson.JsonSyntaxException: Unknown item 'rpgsmw:deleted_mod_element'
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:draco_samurai_boots as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe reliquary:rib_bone as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:tyr_samurai_leggings as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:etyrite_samruai_chestplate_smithing as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:draco_samurai_leggings as it's serializer returned null
# [02:00:14 ERROR]: Parsing error loading recipe alexsdelight:barbecue_on_a_stick: com.google.gson.JsonSyntaxException: Unknown item 'amfd:singular_cooked_moose_rib'
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:brass_repair_kit_mechanical_crafting as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:living_samruai_boots_array as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:living_samruai_boots_helmet as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:etyrite_samruai_leggings_smithing as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe reliquary:frozen_core as it's serializer returned null
# [02:00:14 ERROR]: Parsing error loading recipe magistuarmory:giant_plume: com.google.gson.JsonSyntaxException: Unknown item 'magistuarmory:giant_plume'
# [02:00:14 ERROR]: Parsing error loading recipe epicsamurai:mask_amethyst_samurai_helmet: com.google.gson.JsonSyntaxException: Unknown item 'epicsamurai:mask_amethyst_samurai_helmet'
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:sculk_samruai_chestplate_smithing as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:brass_samruai_leggings_mechanical_crafting as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe reliquary:zombie_heart as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe reliquary:eye_of_the_storm as it's serializer returned null
# [02:00:14 ERROR]: Parsing error loading recipe rpgsmw:b: com.google.gson.JsonSyntaxException: Unknown item 'rpgsmw:deleted_mod_element'
# [02:00:14 INFO]: Skipping loading recipe reliquary:molten_core as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:living_samruai_leggings_array as it's serializer returned null
# [02:00:14 ERROR]: Parsing error loading recipe epicsamurai:mask_netherite_samurai_helmet: com.google.gson.JsonSyntaxException: Unknown item 'epicsamurai:mask_netherite_samurai_helmet'
# [02:00:14 ERROR]: Parsing error loading recipe rpgsmw:nca: com.google.gson.JsonSyntaxException: Unknown item 'rpgsmw:deleted_mod_element'
# [02:00:14 ERROR]: Parsing error loading recipe rpgsmw:ncc: com.google.gson.JsonSyntaxException: Unknown item 'rpgsmw:deleted_mod_element'
# [02:00:14 INFO]: Skipping loading recipe reliquary:withered_rib as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe reliquary:bat_wing as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:sculk_samruai_helmet_smithing as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:tyr_samurai_chestplate as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:tyr_samurai_boots as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:living_samruai_chestplate_array as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe reliquary:nebulous_heart as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:etyrite_samruai_helmet_smithing as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe reliquary:catalyzing_gland as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:draco_samurai_chestplate as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe reliquary:slime_pearl as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:draco_samurai_helmet as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:sculk_samruai_leggings_smithing as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe reliquary:guardian_spike as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:brass_samruai_boots_mechanical_crafting as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe reliquary:chelicerae as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:tyr_samurai_helmet as it's serializer returned null
# [02:00:14 INFO]: Skipping loading recipe epicsamurai:etyrite_samruai_boots_smithing as it's serializer returned null
# [02:00:14 ERROR]: Parsing error loading recipe epicsamurai:mask_straw_hat: com.google.gson.JsonSyntaxException: Unknown item 'epicsamurai:mask_straw_hat'
# [02:00:14 INFO]: Loaded 39 recipes
# [02:00:15 INFO]: Loaded 4892 advancements
# [02:00:15 INFO]: Clearing item tag to light level mapping cache
# [02:00:15 INFO]: Successfully added new Challenger Mob mighty (vtweaks:mighty)
# [02:00:15 INFO]: Successfully added new Challenger Mob pyro (vtweaks:pyro)
# [02:00:15 INFO]: Successfully added new Challenger Mob ranger (vtweaks:ranger)
# [02:00:15 INFO]: Successfully added new Challenger Mob eldritch (vtweaks:eldritch)
# [02:00:15 INFO]: Successfully added new Challenger Mob zistonian (vtweaks:zistonian)
# [02:00:15 INFO]: Successfully added new Challenger Mob agile (vtweaks:agile)
# [02:00:15 INFO]: Successfully added new Challenger Mob arcane (vtweaks:arcane)
# [02:00:15 INFO]: Loaded vtweaks:culled_entities into EntityCullingRule for Entities[minecraft:creeper] + [] in Biomes [] + [TagKey[minecraft:worldgen/biome / minecraft:is_beach]] In [vtweaks:made_up_for_this_test_file]
# [02:00:15 INFO]: Loaded 13 curio slots
# [02:00:15 INFO]: Loaded 1 curio entities
# [02:00:15 INFO]: Trying to load unloaded files from: config/bountiful/bounty_pools
# [02:00:15 INFO]: Trying to load unloaded files from: config/bountiful/bounty_decrees
# [02:00:15 ERROR]: Bountiful compatibility is not enabled for Better Village and Bountiful is present in your mod list.
#      - Please install the datapack for better compatibility between Better Villages and Bountiful.
#      - You can find the datapack URL in the `compatibility` section of the Better Villages description.
#      - URL=https://www.curseforge.com/minecraft/mc-mods/better-village-forge
# [02:00:15 ERROR]: Ice And Fire compatibility is not enabled for Better Village and Ice And Fire is present in your mod list.
#      - Please install the datapack for better compatibility between Better Villages and Ice And Fire.
#      - You can find the datapack URL in the `compatibility` section of the Better Villages description.
#      - URL=https://www.curseforge.com/minecraft/mc-mods/better-village-forge
# [02:00:15 INFO]: Loading data...
# [02:00:15 INFO]: Done.
# [02:00:16 INFO]: Starting minecraft server version 1.20.1
# [02:00:16 INFO]: Loading properties
# [02:00:16 INFO]: Default game type: SURVIVAL
# [02:00:16 INFO]: Generating keypair
# [02:00:16 INFO]: Starting Minecraft server on *:25565
# [02:00:16 INFO]: Using epoll channel type
# [02:00:16 WARN]: **** SERVER IS RUNNING IN OFFLINE/INSECURE MODE!
# [02:00:16 WARN]: The server will make no attempt to authenticate usernames. Beware.
# [02:00:16 WARN]: While this makes the game possible to play without internet access, it also opens up the ability for hackers to connect with any username they choose.
# [02:00:16 WARN]: To change this, set "online-mode" to "true" in the server.properties file.
# [02:00:16 INFO]: This server is running Mohist version 1.20.1-580 (MC: 1.20.1) (Implementing API version 1.20.1-R0.1-SNAPSHOT, Forge version 47.2.20, NeoForge version 47.1.79)
# [02:00:20 INFO]: Debug logging is enabled
# [02:00:20 INFO]: Server Ping Player Sample Count: 20
# [02:00:20 INFO]: Using 4 threads for Netty based IO
# [02:00:20 INFO]: Hello Plugins!
# [02:00:20 INFO]: Loading server config for easyanvils
# [02:00:20 INFO]: Loading server config for easymagic
# [02:00:20 INFO]: Loading JourneyMap Forge Configs
# [02:00:20 INFO]: Loading server config for moblassos
# [02:00:20 INFO]: item config parser identified itemstack 1 torch
# [02:00:20 INFO]: item config parser identified itemstack 1 glowstone
# [02:00:20 INFO]: item config parser finished, item count: 2
# [02:00:20 INFO]: item config parser identified itemstack 1 torch
# [02:00:20 INFO]: item config parser finished, item count: 1
# [02:00:20 INFO]: item config parser identified itemstack 1 torch
# [02:00:20 INFO]: item config parser identified itemstack 1 glowstone
# [02:00:20 INFO]: item config parser finished, item count: 2
# [02:00:20 INFO]: item config parser identified itemstack 1 torch
# [02:00:20 INFO]: item config parser finished, item count: 1
# [02:00:21 INFO]: Starting background profiler...
# [02:00:21 INFO]: Loading server configs...
# [02:00:22 INFO]: Initialized TerraBlender biomes for level stem minecraft:the_nether
# [02:00:22 INFO]: Initialized TerraBlender biomes for level stem minecraft:overworld
# [02:00:22 INFO]: Preparing level "world"
# [02:00:23 INFO]: Preparing start region for dimension minecraft:overworld
# [02:00:23 WARN]: Method overwrite conflict for removeIf in canary.mixins.json:world.chunk_tickets.SortedArraySetMixin, previously written by org.embeddedt.modernfix.common.mixin.bugfix.paper_chunk_patches.SortedArraySetMixin. Skipping method.
# [02:00:25 INFO]: Time elapsed: 597988 ms
# [02:00:25 INFO]: Loaded config for: connectivity.json
# [02:00:25 INFO]: Preparing start region for dimension minecraft:the_end
# [02:00:34 INFO]: Time elapsed: 607121 ms
# [02:00:34 INFO]: Preparing start region for dimension minecraft:the_nether
# [02:00:58 INFO]: Time elapsed: 630480 ms
# [02:00:58 INFO]: [Mohist] Enabling Mohist v1.20.1
# [02:00:58 INFO]: Server permissions file permissions.yml is empty, ignoring it
# [02:00:58 INFO]: Done (38.492s)! For help, type "help"
# [02:00:58 INFO]: Successfully initialized permission handler forge:default_handler
# [02:00:58 INFO]: Forwarding forge permission[forge:default_handler] to bukkit[mohist:permission]
# [02:00:58 INFO]: Thanks for choosing Incendium!
# [02:00:58 INFO]: HELLO from server starting
# [02:00:58 INFO]: Thanks for choosing AmplifiedNether!
# [02:00:58 INFO]: Registering Bounty Board Jigsaw Piece for Village Type: plains
# [02:00:58 INFO]: Registering Bounty Board Jigsaw Piece for Village Type: savanna
# [02:00:58 INFO]: Registering Bounty Board Jigsaw Piece for Village Type: snowy
# [02:00:58 INFO]: Registering Bounty Board Jigsaw Piece for Village Type: taiga
# [02:00:58 INFO]: Registering Bounty Board Jigsaw Piece for Village Type: desert
# [02:00:58 INFO]: Thanks for choosing Terralith!
# [02:00:58 INFO]: Thanks for choosing Nullscape!
# [02:00:58 INFO]: Loaded config for: farsight.json
# [02:00:58 INFO]: Loaded config for: betterfpsdist.json
# [02:00:58 INFO]: {iceandfire:fire_dragon_roost=true, iceandfire:fire_lily=true, iceandfire:spawn_dragon_skeleton_fire=true, iceandfire:lightning_dragon_roost=true, iceandfire:spawn_dragon_skeleton_lightning=true, iceandfire:ice_dragon_roost=true, iceandfire:ice_dragon_cave=true, iceandfire:lightning_dragon_cave=true, iceandfire:cyclops_cave=true, iceandfire:spawn_wandering_cyclops=true, iceandfire:spawn_sea_serpent=true, iceandfire:frost_lily=true, iceandfire:hydra_cave=true, iceandfire:lightning_lily=true, iceandfire:pixie_village=true, iceandfire:myrmex_hive_jungle=true, iceandfire:myrmex_hive_desert=true, iceandfire:silver_ore=true, iceandfire:siren_island=true, iceandfire:spawn_dragon_skeleton_ice=true, iceandfire:spawn_stymphalian_bird=true, iceandfire:fire_dragon_cave=true, iceandfire:sapphire_ore=true, iceandfire:spawn_hippocampus=true, iceandfire:spawn_death_worm=true}
# [02:00:58 INFO]: {TROLL_S=true, HIPPOGRYPH=true, AMPHITHERE=true, COCKATRICE=true, TROLL_M=true, DREAD_LICH=true, TROLL_F=true}
# [02:00:58 INFO]: Sending reload packet to clients
# [02:00:58 WARN]: Dedicated server took 96.515 seconds to load
# [02:00:59 INFO]: Canary Cached BlockState Flags are disabled!
# [02:04:55 INFO]: J4O3 joined the game
# [02:04:55 INFO]: Syncing config to J4O3 (d3640197-d2fd-3cfa-953c-bad862f48693)
# [02:04:55 INFO]: J4O3[/127.0.0.1:33432] logged in with entity id 163 at ([world]119.55859028269865, 8.0, -381.8127823956105)
# [02:06:41 INFO]: Thunder04Wolf joined the game
# [02:06:41 INFO]: Syncing config to Thunder04Wolf (6fdf2eda-4c99-3733-bcad-b732ef9e440b)
# ...
# [05:00:51 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=-562, y=-41, z=-2328}
# [05:00:51 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=-502, y=-18, z=-2313}
# [05:00:55 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=-622, y=-21, z=-2322}
# [05:00:55 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=-614, y=-44, z=-2277}
# [05:01:31 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=-643, y=-34, z=-2051}
# [05:01:31 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=-636, y=-33, z=-2050}
# [05:01:32 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=-698, y=-49, z=-2075}
# [05:01:37 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=-736, y=-26, z=-2170}
# [05:01:51 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=-485, y=-4, z=-1995}
# [05:01:52 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=-706, y=21, z=-2291}
# [05:01:56 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=-437, y=-15, z=-2064}
# [05:02:00 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=-431, y=-40, z=-2151}
# [05:02:01 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [05:02:01 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [05:02:01 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [05:02:01 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [05:02:01 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [05:02:01 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [05:02:01 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [05:02:01 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [05:02:01 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [05:02:01 WARN]: Empty or non-existent pool: minecraft:witch_hut/foundation
# [05:02:03 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=-783, y=-50, z=-1946}
# [05:02:13 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=-809, y=38, z=-2345}
# [05:02:15 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=-831, y=-42, z=-2279}
# [05:02:20 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=-835, y=36, z=-2082}
# [05:02:20 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=-843, y=-52, z=-2075}
# [05:02:34 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=-864, y=-22, z=-2315}
# [05:02:35 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=-838, y=-5, z=-2334}
# [05:02:36 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=-669, y=-18, z=-2451}
# [05:02:36 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=-687, y=-17, z=-2450}
# [05:03:15 INFO]: Named entity Spider['Challenger Mob'/111347, l='ServerLevel[world]', x=-622.56, y=-29.00, z=-2385.51] died: Challenger Mob was slain by entity.enemyexpansion.ladybug
# [05:03:25 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=-822, y=-20, z=-2594}
# [05:03:26 INFO]: Named entity Spider['Challenger Mob'/111348, l='ServerLevel[world]', x=-622.48, y=-28.63, z=-2378.64] died: Challenger Mob was slain by entity.enemyexpansion.ladybug
# [05:03:33 INFO]: Named entity Skeleton['Challenger Mob'/111525, l='ServerLevel[world]', x=-672.09, y=-26.00, z=-2396.70] died: Challenger Mob was slain by entity.born_in_chaos_v1.dread_hound
# [05:04:04 INFO]: Thunder04Wolf has made the advancement [advancements.iceandfire.kill_a_dragon.title]
# [05:05:42 INFO]: Named entity Creeper['Challenger Mob'/110832, l='ServerLevel[world]', x=-623.85, y=51.00, z=-2447.57] died: Challenger Mob was slain by Thunder04Wolf
# [05:06:05 INFO]: Named entity Skeleton['Challenger Mob'/112122, l='ServerLevel[world]', x=-644.61, y=-31.00, z=-2384.36] died: Challenger Mob was slain by entity.born_in_chaos_v1.dread_hound
# [05:08:38 INFO]: Named entity Skeleton['Challenger Mob'/112382, l='ServerLevel[world]', x=-653.30, y=-16.00, z=-2438.87] died: Challenger Mob was slain by entity.born_in_chaos_v1.dread_hound
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [05:15:35 INFO]: Named entity Skeleton['Challenger Mob'/114619, l='ServerLevel[world]', x=-302.05, y=14.00, z=-2737.92] died: Challenger Mob was slain by entity.born_in_chaos_v1.dread_hound
# [05:15:38 WARN]: Rikku (vehicle of Thunder04Wolf) moved wrongly! 1.038610238309957
# [05:15:51 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=115, y=-50, z=-2714}
# [05:15:56 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=185, y=-20, z=-2800}
# [05:15:56 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=180, y=33, z=-2743}
# [05:16:02 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=245, y=28, z=-2748}
# [05:16:03 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=278, y=23, z=-2785}
# [05:16:03 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=287, y=-16, z=-2790}
# [05:16:07 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=331, y=-39, z=-2625}
# [05:16:19 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=440, y=-37, z=-2618}
# [05:16:34 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=229, y=24, z=-3074}
# > Lista de usuarios:
# Nombre: Leanne Graham, Email: Sincere@april.biz
# Nombre: Ervin Howell, Email: Shanna@melissa.tv
# Nombre: Clementine Bauch, Email: Nathan@yesenia.net
# Nombre: Patricia Lebsack, Email: Julianne.OConner@kory.org
# Nombre: Chelsey Dietrich, Email: Lucio_Hettinger@annie.ca
# Nombre: Mrs. Dennis Schulist, Email: Karley_Dach@jasper.info
# Nombre: Kurtis Weissnat, Email: Telly.Hoeger@billy.biz
# Nombre: Nicholas Runolfsdottir V, Email: Sherwood@rosamond.me
# Nombre: Glenna Reichert, Email: Chaim_McDermott@dana.io
# Nombre: Clementina DuBuque, Email: Rey.Padberg@karina.biz
# [05:19:41 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=-192, y=27, z=-3226}
# [05:19:44 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=-244, y=24, z=-3174}
# [05:19:47 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=-304, y=26, z=-3088}
# [05:20:07 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=-489, y=-51, z=-3006}
# [05:20:38 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=41, y=38, z=-2393}
# [05:20:41 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=82, y=-35, z=-2338}
# [05:20:50 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=182, y=-21, z=-2410}
# [05:20:56 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=334, y=-45, z=-2528}
# [05:20:57 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=338, y=34, z=-2508}
# [05:20:59 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=397, y=29, z=-2605}
# [05:21:03 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=451, y=-48, z=-2605}
# [05:21:04 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=459, y=-24, z=-2407}
# [05:21:04 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=493, y=7, z=-2571}
# [05:21:05 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=501, y=29, z=-2589}
# [05:21:06 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=539, y=-28, z=-2622}
# [05:21:08 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=361, y=15, z=-2341}
# [05:21:08 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=547, y=17, z=-2455}
# [05:21:09 WARN]: Rikku (vehicle of Thunder04Wolf) moved wrongly! 0.48419299268852
# [05:21:09 WARN]: Rikku (vehicle of Thunder04Wolf) moved wrongly! 1.4485219086322445
# [05:21:30 WARN]: Rikku (vehicle of Thunder04Wolf) moved wrongly! 0.6820152910654542
# [05:21:30 WARN]: Rikku (vehicle of Thunder04Wolf) moved wrongly! 1.6818154153972387
# [05:21:32 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=601, y=28, z=-2461}
# [05:21:38 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=485, y=-37, z=-2322}
# [05:21:42 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=501, y=-8, z=-2311}
# [05:22:10 WARN]: Rikku (vehicle of Thunder04Wolf) moved wrongly! 0.4610539910991065
# [05:22:10 WARN]: Rikku (vehicle of Thunder04Wolf) moved wrongly! 1.0
# [05:22:44 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=532, y=-41, z=-2083}
# [05:22:54 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=446, y=1, z=-2194}
# [05:22:54 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=438, y=1, z=-2112}
# [05:22:58 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=496, y=-17, z=-1908}
# [05:22:58 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=484, y=-14, z=-1915}
# [05:22:58 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=631, y=-51, z=-1896}
# [05:23:02 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=382, y=-31, z=-2070}
# [05:23:07 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=359, y=-5, z=-2264}
# [05:23:10 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=353, y=25, z=-1946}
# [05:23:11 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=321, y=-14, z=-2117}
# [05:23:11 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=310, y=34, z=-2191}
# [05:23:16 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=325, y=-43, z=-1915}
# [05:23:21 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=331, y=-8, z=-1862}
# [05:23:22 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=163, y=-9, z=-2143}
# [05:23:22 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=170, y=5, z=-2212}
# [05:23:23 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=158, y=10, z=-2192}
# [05:23:23 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=137, y=4, z=-2155}
# [05:23:24 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=114, y=-42, z=-2086}
# [05:23:24 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=104, y=-45, z=-2100}
# [05:23:24 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=101, y=-51, z=-2126}
# [05:23:24 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=179, y=-30, z=-2282}
# [05:23:25 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=247, y=-20, z=-2316}
# [05:23:25 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=63, y=7, z=-2245}
# [05:23:27 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=29, y=-14, z=-2271}
# [05:24:13 WARN]: Rikku (vehicle of Thunder04Wolf) moved wrongly! 0.48997973587001165
# [05:24:27 WARN]: Tried to load a block entity for block Block{minecraft:fletching_table} but failed at location BlockPos{x=-81, y=20, z=-2165}
# [05:24:28 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=-98, y=-22, z=-2037}
# [05:24:30 WARN]: Tried to load a block entity for block Block{minecraft:smithing_table} but failed at location BlockPos{x=-153, y=32, z=-2167}
# [05:25:44 INFO]: Named entity Zombie['Challenger Mob'/125272, l='ServerLevel[world]', x=-306.32, y=-12.66, z=109.65] died: Challenger Mob was slain by entity.enemyexpansion.troll
# [05:27:59 INFO]: Thunder04Wolf lost connection: Disconnected
# [05:27:59 INFO]: Thunder04Wolf left the game
# >
# >=>
# >[05:28:10 INFO]: Stopping server
# [05:28:10 INFO]: [Mohist] Disabling Mohist v1.20.1
# [05:28:10 INFO]: Saving players
# [05:28:10 INFO]: Saving worlds
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 261
#     258 # Ciclo para realizar las solicitudes a JSONPlaceholder cada minuto
#     260 while True:
# --> 261     time.sleep(60)
#
# KeyboardInterrupt:
